# %% [markdown]
# ## Importing necessary libraries

# %%
import tensorflow as tf

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split

# %%
import pickle

# %% [markdown]
# ## Importing resource and display

# %%
original_dataframe  = pd.read_csv('https://raw.githubusercontent.com/IT21034268/shared-location/refs/heads/other-data-01/student-performance-predictions/student_performance-02.csv')

# %%
edited_dataframe = original_dataframe

# %%
edited_dataframe.head(5)
# Out:
#    Gender  AttendanceRate  AttendanceRateNormal  StudyHoursPerWeek  \
# 0       1              82                  0.48                 12
# 1       1              85                  0.60                 15
# 2       1              92                  0.88                 25
# 3       0              90                  0.80                 20
# 4       0              88                  0.72                 18
#
#    StudyHoursPerWeekNormal  PreviousGrade  ExtracurricularActivities  \
# 0                -0.877338             70                          2
# 1                -0.415581             78                          1
# 2                 1.123609             90                          3
# 3                 0.354014             85                          2
# 4                 0.046176             82                          2
#
#    ParentalSupport  FinalGrade
# 0                0          72
# 1                2          80
# 2                2          92
# 3                1          87
# 4                1          85

# %%
model_01 = None
model_02 = None
model_03 = None

# %% [markdown]
# ## Pre-Processing for `model_01`

# %%
columns_to_have_in_x = ['Gender', 'AttendanceRateNormal', 'StudyHoursPerWeekNormal', 'PreviousGrade', 'ExtracurricularActivities']
x = edited_dataframe[columns_to_have_in_x]

# %%
columns_to_have_in_y = ['ParentalSupport']
y = edited_dataframe[columns_to_have_in_y]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
x_train_t = tf.convert_to_tensor(x_train)
x_test_t = tf.convert_to_tensor(x_test)


y_train_t = tf.convert_to_tensor(y_train)
y_test_t = tf.convert_to_tensor(y_test)

# %% [markdown]
# ## `model_01` information

# %%
x_var_count = len(columns_to_have_in_x)

# %%
x_var_count
# Out:
# 5

# %%
# Set the random seed
tf.random.set_seed(42)

# Create the model
model_01 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(x_var_count, )),
    tf.keras.layers.Dense(5, activation="relu"),
    tf.keras.layers.Dense(4, activation="relu"),
    tf.keras.layers.Dense(3, activation='softmax')
])

# Compile the model
model_01.compile(
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                  optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
                  metrics=["accuracy"]
                )

# Fit the model
history_01 = model_01.fit(x_train_t, y_train_t, epochs=20)
# Out:
# Epoch 1/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.2857 - loss: 32.3598
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.2857 - loss: 29.6831
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.2857 - loss: 27.1061
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.2857 - loss: 24.6287
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.2857 - loss: 22.2509
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.2857 - loss: 19.9719
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.2857 - loss: 17.7908
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2857 - loss: 15.7062
# Epoch 9/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.2857 - loss: 13.7164
# Epoch 10/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2857 - loss: 11.8195
# Epoch 11/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.2857 - loss: 10.0155
# Epoch 12/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.2857 - loss: 8.3219
# Epoch 13/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.2857 - loss: 6.8682
# Epoch 14/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.4286 - loss: 6.1043
# Epoch 15/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.4286 - loss: 6.0838
# Epoch 16/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4286 - loss: 6.2074
# Epoch 17/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.4286 - loss: 6.2557
# Epoch 18/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.4286 - loss: 6.2065
# Epoch 19/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.4286 - loss: 6.0712
# Epoch 20/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.4286 - loss: 5.8649

# %%
# Save the model to a pickle file
filename = 'model_01.pkl'
with open(filename, 'wb') as file:
    pickle.dump(model_01, file)

# %%
# Open the saved pickle file
with open('model_01.pkl', 'rb') as file:
    model_01 = pickle.load(file)

# %%
model_01.evaluate(x_test_t, y_test_t)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - accuracy: 0.0000e+00 - loss: 7.8388
# [7.8387579917907715, 0.0]

# %% [markdown]
# ## Pre-Processing for `model_02`

# %%
columns_to_have_in_x = ['Gender', 'AttendanceRateNormal', 'StudyHoursPerWeekNormal', 'PreviousGrade', 'ExtracurricularActivities']
x = edited_dataframe[columns_to_have_in_x]

# %%
columns_to_have_in_y = ['ParentalSupport']
y = edited_dataframe[columns_to_have_in_y]

# %%
y = pd.get_dummies(y['ParentalSupport'])

# %%
y
# Out:
#        0      1      2
# 0   True  False  False
# 1  False  False   True
# 2  False  False   True
# 3  False   True  False
# 4  False   True  False
# 5   True  False  False
# 6  False   True  False
# 7   True  False  False
# 8  False  False   True
# 9  False  False   True

# %%
# y = y.applymap(lambda x: 1 if x else 0)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
x_train_t = tf.convert_to_tensor(x_train)
x_test_t = tf.convert_to_tensor(x_test)


y_train_t = tf.convert_to_tensor(y_train)
y_test_t = tf.convert_to_tensor(y_test)

# %%
y_train_t = tf.cast(y_train_t, tf.int32)

# %%
y_test_t = tf.cast(y_test_t, tf.int32)

# %% [markdown]
# ## `model_02` information

# %%
x_var_count = len(columns_to_have_in_x)

# %%
x_var_count
# Out:
# 5

# %%
# Set the random seed
tf.random.set_seed(42)

# Create the model
model_02 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(x_var_count, )),
    tf.keras.layers.Dense(5, activation="relu"),
    tf.keras.layers.Dense(4, activation="relu"),
    tf.keras.layers.Dense(3, activation='softmax')
])

# Compile the model
model_02.compile(
                  loss=tf.keras.losses.CategoricalCrossentropy(),
                  optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
                  metrics=["accuracy"]
                )

# Fit the model
history_02 = model_02.fit(x_train_t, y_train_t, epochs=20)
# Out:
# Epoch 1/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.2857 - loss: 2.7218
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.2857 - loss: 2.2179
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2857 - loss: 1.8189
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.2857 - loss: 1.5401
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.2857 - loss: 1.3733
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4286 - loss: 1.2798
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7143 - loss: 1.2192
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7143 - loss: 1.1724
# Epoch 9/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5714 - loss: 1.1361
# Epoch 10/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5714 - loss: 1.1119
# Epoch 11/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.4286 - loss: 1.1006
# Epoch 12/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.4286 - loss: 1.1000
# Epoch 13/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.4286 - loss: 1.1054
# Epoch 14/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.2857 - loss: 1.1118
# Epoch 15/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.1429 - loss: 1.1157
# Epoch 16/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.2857 - loss: 1.1159
# Epoch 17/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.2857 - loss: 1.1132
# Epoch 18/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4286 - loss: 1.1088
# Epoch 19/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.4286 - loss: 1.1040
# Epoch 20/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.4286 - loss: 1.0999

# %%
# Save the model to a pickle file
filename = 'model_02.pkl'
with open(filename, 'wb') as file:
    pickle.dump(model_02, file)

# %%
# Open the saved pickle file
with open('model_02.pkl', 'rb') as file:
    model_02 = pickle.load(file)

# %%
model_02.evaluate(x_test_t, y_test_t)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_test_function.<locals>.one_step_on_iterator at 0x7e9817c2bbe0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.0000e+00 - loss: 1.2437
# [1.2436723709106445, 0.0]

# %% [markdown]
# ## Pre-Processing for `model_03`

# %%
columns_to_have_in_x = ['AttendanceRateNormal', 'StudyHoursPerWeekNormal', 'PreviousGrade', 'ExtracurricularActivities', 'ParentalSupport']
x = edited_dataframe[columns_to_have_in_x]

# %%
columns_to_have_in_y = ['Gender']
y = edited_dataframe[columns_to_have_in_y]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
x_train_t = tf.convert_to_tensor(x_train)
x_test_t = tf.convert_to_tensor(x_test)


y_train_t = tf.convert_to_tensor(y_train)
y_test_t = tf.convert_to_tensor(y_test)

# %% [markdown]
# ## `model_03` information

# %%
x_var_count = len(columns_to_have_in_x)

# %%
x_var_count
# Out:
# 5

# %%
# Set the random seed
tf.random.set_seed(42)

# Create the model
model_03 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(x_var_count, )),
    tf.keras.layers.Dense(5, activation="relu"),
    tf.keras.layers.Dense(4, activation="relu"),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compile the model
model_03.compile(
                  loss=tf.keras.losses.BinaryCrossentropy(),
                  optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
                  metrics=["accuracy"]
                )

# Fit the model
history_03 = model_03.fit(x_train_t, y_train_t, epochs=20)
# Out:
# Epoch 1/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4286 - loss: 3.6508
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4286 - loss: 1.7342
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4286 - loss: 0.8389
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5714 - loss: 0.7081
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5714 - loss: 0.7316
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5714 - loss: 0.8344
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5714 - loss: 0.9150
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5714 - loss: 0.9430
# Epoch 9/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5714 - loss: 0.9222
# Epoch 10/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5714 - loss: 0.8670
# Epoch 11/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5714 - loss: 0.7965
# Epoch 12/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5714 - loss: 0.7323
# Epoch 13/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5714 - loss: 0.6954
# Epoch 14/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5714 - loss: 0.6970
# Epoch 15/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.2857 - loss: 0.7278
# Epoch 16/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.4286 - loss: 0.7625
# Epoch 17/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.4286 - loss: 0.7781
# Epoch 18/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.4286 - loss: 0.7678
# Epoch 19/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.4286 - loss: 0.7396
# Epoch 20/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.1429 - loss: 0.7083

# %%
# Save the model to a pickle file
filename = 'model_03.pkl'
with open(filename, 'wb') as file:
    pickle.dump(model_03, file)

# %%
# Open the saved pickle file
with open('model_03.pkl', 'rb') as file:
    model_03 = pickle.load(file)

# %%
model_03.evaluate(x_test_t, y_test_t)
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_test_function.<locals>.one_step_on_iterator at 0x7e981791bd90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.3333 - loss: 0.7386
# [0.7385902404785156, 0.3333333432674408]
